# %% [markdown]
# <a href="https://colab.research.google.com/github/sugatoray/CodeSnippets/blob/master/xkcd_fun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fun with `xkcd`**
# >xkcd, sometimes styled XKCD, is a webcomic created in 2005 by American author Randall Munroe. The comic's tagline describes it as "A webcomic of romance, sarcasm, math, and language". Munroe states on the comic's website that the name of the comic is not an initialism, but "just a word with no phonetic pronunciation". -- [Wikipedia](https://en.wikipedia.org/wiki/Xkcd)
#
# The all-famous plotting library in python, **Matplotlib** offers an `xkcd`-flavoured plotting option. We will explore a bit of this and have fun!
# 😍 😎 😀
#
# **Note**:
# 1. The emoji-icons were copy-pasted from **http://getemoji.com/**.
# 1. Also make note of this github-repo on cheat-sheet for emoji: https://github.com/ikatyang/emoji-cheat-sheet.
# 1. Github imoji API: https://api.github.com/emojis
# 1. [**Have fun with Emojis in Jupyter Notebook**](https://medium.com/@sawanrai777/have-fun-with-emojis-in-jupyter-notebook-f74db7f45210)
#
#
# [//]: # (This is a comment)
# [//]: # (The emoji-icons were copy-pasted from "http://getemoji.com/")
#
# ![Fun with xkcd](https://imgs.xkcd.com/comics/bag_check.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # 'svg', 'retina'
plt.style.use('seaborn-white')

# %%
# Make data
x = np.arange(-0.7, 7, 0.1)
y = 0.6*(x**2 - 8*x + 10)

# %% [markdown]
# ## **Show Figure in _`xkcd`_-Style**
#
# You can make a regular plot with matplotlib. But then to add some `xkcd`-type features to it, all you need is the `plt.xkcd()` context manager. Anything that goes inside the context manager will have the `xkcd`-formatted-layout.
#
# ```python
# with plt.xkcd():
#     plt.plot(x,y)
#     #... your codes goes here
# ```

# %%
with plt.xkcd():
    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Demo: xkcd-style plot')
    #plt.legend()
    plt.show()

# %% [markdown]
# # **Show Image**
#
# We will pull image data from an _image-url_, read it with `skimage.io.imread(url)` and then show it with `plt.imshow(image)` as follows.

# %%
image_url = r"https://s.ftcdn.net/v2013/pics/all/curated/RKyaEDwp8J7JKeZWQPuOVWvkUjGQfpCx_cover_580.jpg?r=1a0fc22192d0c808b8bb2b9bcfbf4a45b1793687"

# %%
#!pip install scikit-image
from skimage import io
#import matplotlib.pyplot as plt

# create a file-like object from the url
url = image_url

# read the image file in a numpy array
image = io.imread(url)
plt.imshow(image)
plt.show()

# %% [markdown]
# ## **Show Image in _`xkcd`_-Style**

# %%
with plt.xkcd():
    plt.imshow(image)
    #plt.gca().set_axis_off()
    plt.yticks(ticks=[]) # set yticks off
    plt.xticks(ticks=[]) # set xticks off
    plt.title('xkcd-Styled Image Display')
    plt.show()
